# %% [markdown]
# # Exploratory Data Analysis
#
# Source: `C:\Users\mohds\delivery-engine\data\DataCoSupplyChainDataset_utf8.csv`
#
# Every figure in this notebook was computed by the deterministic engine and injected from the hashed Findings Store. The AI wrote structure and prose only.
#
# - dq_profile findings hash: `25cd00114eff27c8c52088d59c933dca5430f3d2f7e3ec543cd012f63273236f`
# - dq_validate findings hash: `01e2f211f5264bd59c6d536451f6765d4da61e63d6cdcf741291140ecbae891d`

# %% [markdown]
# ## Data quality scorecard (DAMA six dimensions)
#
# | Dimension | Score |
# |---|---|
# | accuracy | not scored |
# | completeness | 96.5% |
# | consistency | 99.7% |
# | timeliness | not scored |
# | uniqueness | 100.0% |
# | validity | 94.3% |
#
# Accuracy is never scored from the dataset alone - that requires reconciliation against an authoritative source.

# %% [markdown]
# ## Column profile
#
# - **Type** (VARCHAR): 180,519 rows, 0 nulls, 4 distinct, validity 100.0%
# - **Days for shipping (real)** (BIGINT): 180,519 rows, 0 nulls, 7 distinct, validity 100.0%
# - **Days for shipment (scheduled)** (BIGINT): 180,519 rows, 0 nulls, 4 distinct, validity 100.0%
# - **Benefit per order** (DOUBLE): 180,519 rows, 0 nulls, 21,998 distinct, validity 100.0%
# - **Sales per customer** (DOUBLE): 180,519 rows, 0 nulls, 2,927 distinct, validity 100.0%
# - **Delivery Status** (VARCHAR): 180,519 rows, 0 nulls, 4 distinct, validity 100.0%
# - **Late_delivery_risk** (BIGINT): 180,519 rows, 0 nulls, 2 distinct, validity 100.0%
# - **Category Id** (BIGINT): 180,519 rows, 0 nulls, 51 distinct, validity 100.0%
# - **Category Name** (VARCHAR): 180,519 rows, 0 nulls, 50 distinct, validity 100.0%
# - **Customer City** (VARCHAR): 180,519 rows, 0 nulls, 563 distinct, validity 100.0%
# - **Customer Country** (VARCHAR): 180,519 rows, 0 nulls, 2 distinct, validity 100.0%
# - **Customer Email** (VARCHAR): 180,519 rows, 0 nulls, 1 distinct, validity 0.0%
# - **Customer Fname** (VARCHAR): 180,519 rows, 0 nulls, 782 distinct, validity 100.0%
# - **Customer Id** (BIGINT): 180,519 rows, 0 nulls, 20,652 distinct, validity 100.0%
# - **Customer Lname** (VARCHAR): 180,519 rows, 8 nulls, 1,109 distinct, validity 100.0%
# - **Customer Password** (VARCHAR): 180,519 rows, 0 nulls, 1 distinct, validity 100.0%
# - **Customer Segment** (VARCHAR): 180,519 rows, 0 nulls, 3 distinct, validity 100.0%
# - **Customer State** (VARCHAR): 180,519 rows, 0 nulls, 46 distinct, validity 100.0%
# - **Customer Street** (VARCHAR): 180,519 rows, 0 nulls, 7,458 distinct, validity 100.0%
# - **Customer Zipcode** (BIGINT): 180,519 rows, 3 nulls, 995 distinct, validity 100.0%
# - **Department Id** (BIGINT): 180,519 rows, 0 nulls, 11 distinct, validity 100.0%
# - **Department Name** (VARCHAR): 180,519 rows, 0 nulls, 11 distinct, validity 100.0%
# - **Latitude** (DOUBLE): 180,519 rows, 0 nulls, 11,250 distinct, validity 100.0%
# - **Longitude** (DOUBLE): 180,519 rows, 0 nulls, 4,487 distinct, validity 100.0%
# - **Market** (VARCHAR): 180,519 rows, 0 nulls, 5 distinct, validity 100.0%
# - **Order City** (VARCHAR): 180,519 rows, 0 nulls, 3,597 distinct, validity 100.0%
# - **Order Country** (VARCHAR): 180,519 rows, 0 nulls, 164 distinct, validity 100.0%
# - **Order Customer Id** (BIGINT): 180,519 rows, 0 nulls, 20,652 distinct, validity 100.0%
# - **order date (DateOrders)** (VARCHAR): 180,519 rows, 0 nulls, 65,752 distinct, validity 0.0%
# - **Order Id** (BIGINT): 180,519 rows, 0 nulls, 65,752 distinct, validity 100.0%
# - **Order Item Cardprod Id** (BIGINT): 180,519 rows, 0 nulls, 118 distinct, validity 100.0%
# - **Order Item Discount** (DOUBLE): 180,519 rows, 0 nulls, 1,017 distinct, validity 100.0%
# - **Order Item Discount Rate** (DOUBLE): 180,519 rows, 0 nulls, 18 distinct, validity 100.0%
# - **Order Item Id** (BIGINT): 180,519 rows, 0 nulls, 180,519 distinct, validity 100.0%
# - **Order Item Product Price** (DOUBLE): 180,519 rows, 0 nulls, 75 distinct, validity 100.0%
# - **Order Item Profit Ratio** (DOUBLE): 180,519 rows, 0 nulls, 162 distinct, validity 100.0%
# - **Order Item Quantity** (BIGINT): 180,519 rows, 0 nulls, 5 distinct, validity 100.0%
# - **Sales** (DOUBLE): 180,519 rows, 0 nulls, 193 distinct, validity 100.0%
# - **Order Item Total** (DOUBLE): 180,519 rows, 0 nulls, 2,927 distinct, validity 100.0%
# - **Order Profit Per Order** (DOUBLE): 180,519 rows, 0 nulls, 21,998 distinct, validity 100.0%
# - **Order Region** (VARCHAR): 180,519 rows, 0 nulls, 23 distinct, validity 100.0%
# - **Order State** (VARCHAR): 180,519 rows, 0 nulls, 1,089 distinct, validity 100.0%
# - **Order Status** (VARCHAR): 180,519 rows, 0 nulls, 9 distinct, validity 100.0%
# - **Order Zipcode** (BIGINT): 180,519 rows, 155,679 nulls, 609 distinct, validity 100.0%
# - **Product Card Id** (BIGINT): 180,519 rows, 0 nulls, 118 distinct, validity 100.0%
# - **Product Category Id** (BIGINT): 180,519 rows, 0 nulls, 51 distinct, validity 100.0%
# - **Product Description** (VARCHAR): 180,519 rows, 180,519 nulls, 0 distinct, validity 100.0%
# - **Product Image** (VARCHAR): 180,519 rows, 0 nulls, 118 distinct, validity 100.0%
# - **Product Name** (VARCHAR): 180,519 rows, 0 nulls, 118 distinct, validity 100.0%
# - **Product Price** (DOUBLE): 180,519 rows, 0 nulls, 75 distinct, validity 100.0%
# - **Product Status** (BIGINT): 180,519 rows, 0 nulls, 1 distinct, validity 100.0%
# - **shipping date (DateOrders)** (VARCHAR): 180,519 rows, 0 nulls, 63,701 distinct, validity 0.0%
# - **Shipping Mode** (VARCHAR): 180,519 rows, 0 nulls, 4 distinct, validity 100.0%

# %% [markdown]
# ## Validation findings
#
# | Rule | Column | Check | Exceptions |
# |---|---|---|---|
# | `R01` | Order Id | not_null | 0 |
# | `R02` | Sales | range | 0 |
# | `R03` | Order Profit Per Order | range | 0 |
# | `R04` | Order Status | allowed | 15,759 |
# | `R05` | Delivery Status | allowed | 0 |
#
# Exceptions are reported, never dropped - every failure is evidence, not garbage.

# %% [markdown]
# ## Continue the exploration
#
# The cells below are scaffolding for the human analyst - the judgment layer the engine deliberately does not automate.

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\mohds\\delivery-engine\\data\\DataCoSupplyChainDataset_utf8.csv")
df.head()

# %%
# Segment the binary target against each categorical column
# and challenge the engine's findings with your own eyes.
df.describe(include='all')
