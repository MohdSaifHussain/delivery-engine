# %% [markdown]
# # Exploratory Data Analysis
#
# Source: `C:\Users\mohds\delivery-engine\examples\churn_analysis\WA_Fn-UseC_-Telco-Customer-Churn.csv`
#
# Every figure in this notebook was computed by the deterministic engine and injected from the hashed Findings Store. The AI wrote structure and prose only.
#
# - dq_profile findings hash: `851b1ea2b88e9cd8c649a7f44e2e51bfd3511a93dfeb5c89707a91cb6f18f8c2`
# - dq_validate findings hash: `b422f2ebd2aad9b20e122af7c3e7efeffc25e94cdbbd6105cf7d6386776396a3`

# %% [markdown]
# ## Data quality scorecard (DAMA six dimensions)
#
# | Dimension | Score |
# |---|---|
# | accuracy | not scored |
# | completeness | 100.0% |
# | consistency | 100.0% |
# | timeliness | not scored |
# | uniqueness | 100.0% |
# | validity | 100.0% |
#
# Accuracy is never scored from the dataset alone - that requires reconciliation against an authoritative source.

# %% [markdown]
# ## Column profile
#
# - **customerID** (VARCHAR): 7,043 rows, 0 nulls, 7,043 distinct, validity 100.0%
# - **gender** (VARCHAR): 7,043 rows, 0 nulls, 2 distinct, validity 100.0%
# - **SeniorCitizen** (BIGINT): 7,043 rows, 0 nulls, 2 distinct, validity 100.0%
# - **Partner** (BOOLEAN): 7,043 rows, 0 nulls, 2 distinct, validity 100.0%
# - **Dependents** (BOOLEAN): 7,043 rows, 0 nulls, 2 distinct, validity 100.0%
# - **tenure** (BIGINT): 7,043 rows, 0 nulls, 73 distinct, validity 100.0%
# - **PhoneService** (BOOLEAN): 7,043 rows, 0 nulls, 2 distinct, validity 100.0%
# - **MultipleLines** (VARCHAR): 7,043 rows, 0 nulls, 3 distinct, validity 100.0%
# - **InternetService** (VARCHAR): 7,043 rows, 0 nulls, 3 distinct, validity 100.0%
# - **OnlineSecurity** (VARCHAR): 7,043 rows, 0 nulls, 3 distinct, validity 100.0%
# - **OnlineBackup** (VARCHAR): 7,043 rows, 0 nulls, 3 distinct, validity 100.0%
# - **DeviceProtection** (VARCHAR): 7,043 rows, 0 nulls, 3 distinct, validity 100.0%
# - **TechSupport** (VARCHAR): 7,043 rows, 0 nulls, 3 distinct, validity 100.0%
# - **StreamingTV** (VARCHAR): 7,043 rows, 0 nulls, 3 distinct, validity 100.0%
# - **StreamingMovies** (VARCHAR): 7,043 rows, 0 nulls, 3 distinct, validity 100.0%
# - **Contract** (VARCHAR): 7,043 rows, 0 nulls, 3 distinct, validity 100.0%
# - **PaperlessBilling** (BOOLEAN): 7,043 rows, 0 nulls, 2 distinct, validity 100.0%
# - **PaymentMethod** (VARCHAR): 7,043 rows, 0 nulls, 4 distinct, validity 100.0%
# - **MonthlyCharges** (DOUBLE): 7,043 rows, 0 nulls, 1,585 distinct, validity 100.0%
# - **TotalCharges** (VARCHAR): 7,043 rows, 0 nulls, 6,531 distinct, validity 100.0%
# - **Churn** (BOOLEAN): 7,043 rows, 0 nulls, 2 distinct, validity 100.0%

# %% [markdown]
# ## Validation findings
#
# | Rule | Column | Check | Exceptions |
# |---|---|---|---|
# | `R01` | customerID | unique | 0 |
#
# Exceptions are reported, never dropped - every failure is evidence, not garbage.

# %% [markdown]
# ## Continue the exploration
#
# The cells below are scaffolding for the human analyst - the judgment layer the engine deliberately does not automate.

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\mohds\\delivery-engine\\examples\\churn_analysis\\WA_Fn-UseC_-Telco-Customer-Churn.csv")
df.head()

# %%
# Segment the binary target against each categorical column
# and challenge the engine's findings with your own eyes.
df.describe(include='all')
